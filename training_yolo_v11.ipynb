# %% [markdown]
# DATASET DOWNLOAD FROM ROBOFLOW

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="SkmsYhyO83KpYEN4aVSc")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in football-players-detection-1 to yolov11:: 100%|██████████| 147802/147802 [00:33<00:00, 4359.56it/s]
# Extracting Dataset Version Zip to football-players-detection-1 in yolov11:: 100%|██████████| 1338/1338 [00:00<00:00, 3222.09it/s]

# %%
# !yolo task=detect mode=train model=yolo11x.pt data={dataset.location}/data.yaml epochs=10 imgsz=640 batch=4
# Out:
# Ultralytics 8.4.115 🚀 Python-3.11.15 torch-2.13.0+cu130 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/ravjot/football/football-players-detection-1/data.yaml, degrees=0.0, deterministic=True, device=, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=10, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11x.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train-2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/ravjot/football/runs/detect/train-2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2784  ultralytics.nn.modules.conv.Conv             [3, 96, 3, 2]
#   1                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   2                  -1  2    389760  ultralytics.nn.modules.block.C3k2            [192, 384, 2, True, 0.25]
#   3                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#   4                  -1  2   1553664  ultralytics.nn.modules.block.C3k2            [384, 768, 2, True, 0.25]
#   5                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   6                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   7                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   8                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   9                  -1  1   1476864  ultralytics.nn.modules.block.SPPF            [768, 768, 5]
#  10                  -1  2   3264768  ultralytics.nn.modules.block.C2PSA           [768, 768, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2   1700352  ultralytics.nn.modules.block.C3k2            [1536, 384, 2, True]
#  17                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   5317632  ultralytics.nn.modules.block.C3k2            [1152, 768, 2, True]
#  20                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  23        [16, 19, 22]  1   3150172  ultralytics.nn.modules.head.Detect           [4, 16, None, [384, 768, 768]]
# YOLO11x summary: 358 layers, 56,878,396 parameters, 56,878,380 gradients, 195.8 GFLOPs
#
# Transferred 1009/1015 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 5329.7±1223.8 MB/s, size: 226.0 KB)
# train: Scanning /home/ravjot/football/football-players-detection-1/train/labels... 612 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 612/612 793.3it/s 0.8s0.1s
# train: New cache created: /home/ravjot/football/football-players-detection-1/train/labels.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1214.3±967.8 MB/s, size: 209.9 KB)
# val: Scanning /home/ravjot/football/football-players-detection-1/valid/labels... 38 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 38/38 545.5it/s 0.1s
# val: New cache created: /home/ravjot/football/football-players-detection-1/valid/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 167 weight(decay=0.0), 174 weight(decay=0.0005), 173 bias(decay=0.0)
# Plotting labels to /home/ravjot/football/runs/detect/train-2/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /home/ravjot/football/runs/detect/train-2
# Starting training for 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10      4.69G       1.18     0.9297     0.7945         93        640: 100% ━━━━━━━━━━━━ 153/153 3.6it/s 43.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.4it/s 2.1s0.2ss
#                    all         38        905      0.606      0.523      0.559      0.325
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10       4.9G      1.293     0.7095     0.7944         93        640: 100% ━━━━━━━━━━━━ 153/153 4.0it/s 38.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.8it/s 0.6s0.2s
#                    all         38        905      0.681      0.656      0.677      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10       4.9G      1.348      0.754     0.8104         95        640: 100% ━━━━━━━━━━━━ 153/153 4.1it/s 37.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.8it/s 0.6s0.2s
#                    all         38        905       0.62      0.415      0.491      0.223
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10      4.89G      1.252     0.7304     0.7974         87        640: 100% ━━━━━━━━━━━━ 153/153 4.1it/s 37.5s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.7it/s 0.6s0.2s
#                    all         38        905      0.746      0.699      0.735      0.428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10      4.89G      1.175     0.5914      0.791         96        640: 100% ━━━━━━━━━━━━ 153/153 4.1it/s 37.6s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.8it/s 0.6s0.2s
#                    all         38        905      0.713      0.639      0.683      0.406
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      4.89G      1.092     0.5522     0.7801         88        640: 100% ━━━━━━━━━━━━ 153/153 4.1it/s 37.4s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.7it/s 0.6s0.2s
#                    all         38        905      0.834      0.743      0.797      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10       4.9G      1.034     0.4969     0.7767         92        640: 100% ━━━━━━━━━━━━ 153/153 4.1it/s 37.6s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.8it/s 0.6s0.2s
#                    all         38        905       0.85      0.772      0.809      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10       4.9G      1.002     0.4778      0.777         91        640: 100% ━━━━━━━━━━━━ 153/153 4.1it/s 37.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.9it/s 0.6s0.2s
#                    all         38        905      0.834      0.805      0.824      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10      4.89G     0.9466      0.449       0.77         93        640: 100% ━━━━━━━━━━━━ 153/153 4.1it/s 37.6s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.9it/s 0.6s0.2s
#                    all         38        905      0.926      0.798      0.832      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10      4.89G     0.9381     0.4347     0.7683         92        640: 100% ━━━━━━━━━━━━ 153/153 4.1it/s 37.6s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.8it/s 0.6s0.2s
#                    all         38        905      0.897      0.818      0.834      0.561
#
# 10 epochs completed in 0.114 hours.
# Optimizer stripped from /home/ravjot/football/runs/detect/train-2/weights/last.pt, 114.4MB
# Optimizer stripped from /home/ravjot/football/runs/detect/train-2/weights/best.pt, 114.4MB
#
# Validating /home/ravjot/football/runs/detect/train-2/weights/best.pt...
# Ultralytics 8.4.115 🚀 Python-3.11.15 torch-2.13.0+cu130 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# YOLO11x summary (fused): 191 layers, 56,831,644 parameters, 0 gradients, 194.8 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.9it/s 1.3s0.4s
#                    all         38        905      0.881      0.812      0.828      0.554
#                   ball         35         35      0.685        0.4      0.394      0.121
#             goalkeeper         27         27          1      0.877      0.942      0.704
#                 player         38        754       0.94      0.981      0.991      0.754
#                referee         38         89      0.897      0.989      0.984      0.638
# Speed: 0.2ms preprocess, 10.1ms inference, 0.2ms loss, 19.0ms postprocess per image
# Results saved to /home/ravjot/football/runs/detect/train-2
# 💡 Learn more at https://docs.ultralytics.com/modes/train
